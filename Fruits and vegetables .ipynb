# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df= pd.read_csv('Prices.csv')

# %%
df
# Out:
#                            Item    Form  RetailPrice Retail Price Unit  \
# 0                  Acorn squash   Fresh       1.1804         per pound
# 1                        Apples   Fresh       1.5193         per pound
# 2            Apples, applesauce  Canned       1.0660         per pound
# 3    Apples, frozen concentrate   Juice       0.5853          per pint
# 4        Apples, ready-to-drink   Juice       0.7804          per pint
# ..                          ...     ...          ...               ...
# 150               Turnip greens   Fresh       2.4176         per pound
# 151               Turnip greens  Canned       1.0429         per pound
# 152               Turnip greens  Frozen       1.9451         per pound
# 153                  Watermelon   Fresh       0.3604         per pound
# 154                    Zucchini   Fresh       1.5489         per pound
#
#       Yield  Cup Equivalent Size Cup Equivalent Unit  Cup Equivalent Price
# ...

# %% [markdown]
# The column description of the dataset is as follows:
#
# Item: Name of the fruit or the vegetable.
# Form: The form of the item, i.e., canned, fresh, juice, dried or frozen.
# Retail Price: Average retail price of the item in the year.
# Retail Price Unit: Average retail price's measurement unit.
# Yield: Average yield of the item in the year.
# Cup Equivalent Size: Comparison done with one edible cup of food.
# Cup Equivalent Unit: Comparison's measurement unit.
# Cup Equivalent Price: Price per edible cup equivalent (The Unit of Measurement for Federal Recommendations for Fruit and Vegetable Consumption)

# %%
#name of the datasets column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Item                  155 non-null    object
#  1   Form                  155 non-null    object
#  2   RetailPrice           155 non-null    float64
#  3   Retail Price Unit     155 non-null    object
#  4   Yield                 155 non-null    float64
#  5   Cup Equivalent Size   155 non-null    float64
#  6   Cup Equivalent Unit   155 non-null    object
#  7   Cup Equivalent Price  155 non-null    float64
# dtypes: float64(4), object(4)
# memory usage: 9.8+ KB

# %%
#yield 
df.Yield.unique()
# Out:
# array([0.4586, 0.9   , 1.    , 0.93  , 0.65  , 0.375 , 0.4938, 1.0335,
#        0.7408, 0.64  , 2.4692, 0.96  , 2.5397, 0.95  , 0.8818, 0.78  ,
#        1.06  , 0.714 , 0.7788, 0.7791, 0.51  , 0.98  , 0.8158, 0.89  ,
#        0.9304, 0.9702, 0.8926, 0.73  , 0.92  , 0.77  , 1.16  , 0.54  ,
#        0.963 , 0.97  , 0.49  , 0.8466, 0.903 , 0.8924, 0.82  , 0.46  ,
#        1.05  , 0.8995, 0.76  , 0.94  , 0.85  , 1.097 , 0.71  , 0.99  ,
#        0.7478, 0.91  , 0.7695, 0.68  , 0.62  , 0.56  , 0.8113, 0.776 ,
#        0.75  , 0.52  ])

# %%
# Details contained in Form 
df.Form.unique()
# Out:
# array(['Fresh', 'Canned', 'Juice', 'Dried', 'Frozen'], dtype=object)

# %%
#the statistic of the price 
df.describe()
# Out:
#        RetailPrice       Yield  Cup Equivalent Size  Cup Equivalent Price
# count   155.000000  155.000000           155.000000            155.000000
# mean      2.179553    0.926450             0.885175              0.814088
# std       1.559205    0.400215             1.974584              0.485388
# min       0.360400    0.375000             0.123200              0.202100
# 25%       1.156550    0.665000             0.319700              0.519850
# 50%       1.721800    0.910000             0.352700              0.676900
# 75%       2.578300    1.000000             0.385800              1.022300
# max      10.552700    2.539700             8.000000              3.070000

# %% [markdown]
# The statistics of this data sets shows that:
# Average retail price's measurement unit is $2.18(2 d.p),
# Average yield of the item in the year is 0.93
# Comparison done with one edible cup of food is 0.89
#  Price per edible cup equivalent is 0.881

# %%
#number of rows and columns it contains 
df.shape
# Out:
# (155, 8)

# %%
#checking for missing values 
df.isnull().sum()
# Out:
# Item                    0
# Form                    0
# RetailPrice             0
# Retail Price Unit       0
# Yield                   0
# Cup Equivalent Size     0
# Cup Equivalent Unit     0
# Cup Equivalent Price    0
# dtype: int64

# %%
#duplicate value
df.duplicated().sum()

#No duplicates
# Out:
# 0

# %%
#plot for item 
plt.figure(figsize=(8,6))
sns.countplot(data=df, x='Item', hue='Form')
plt.show()

# %%
#plot for Form
plt.figure(figsize=(10,8))
sns.countplot(data=df, x='Form')
plt.title('The Count of the product')
plt.show()

# %%
sns.heatmap(df.corr())
# Out:
# C:\Users\adeye\AppData\Local\Temp\ipykernel_4176\58359773.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %%
#items listed in Item
df.Item.unique()
# Out:
# array(['Acorn squash', 'Apples', 'Apples, applesauce',
#        'Apples, frozen concentrate', 'Apples, ready-to-drink', 'Apricots',
#        'Apricots, packed in juice', 'Apricots, packed in syrup or water',
#        'Artichoke', 'Asparagus', 'Avocados', 'Bananas', 'Beets',
#        'Berries, mixed', 'Black beans', 'Blackberries', 'Blackeye peas',
#        'Blueberries', 'Broccoli', 'Broccoli florets', 'Broccoli heads',
#        'Brussels sprouts', 'Butternut squash', 'Cabbage, green',
#        'Cabbage, red', 'Cabbage, sauerkraut', 'Cantaloupe', 'Carrots',
#        'Carrots, baby', 'Carrots, cooked whole', 'Carrots, raw whole',
#        'Cauliflower', 'Cauliflower florets', 'Cauliflower heads',
#        'Celery sticks', 'Celery, trimmed bunches', 'Cherries',
#        'Cherries, packed in syrup or water', 'Clementines',
#        'Collard greens', 'Corn', 'Cranberries', 'Cucumbers with peel',
#        'Cucumbers without peel', 'Dates', 'Figs',
# ...

# %%
#the relationship between the Forms and the cupequivalent price
plt.title('The Cup Equivalent prices of the Forms')
sns.barplot(data=df, x="Form", y= "Cup Equivalent Price")
plt.show()

# %%
#the relationship between the Retailpriceunit and the cupequivalent price
plt.title('The Retail price per unit versus the cup equivalent price')
sns.barplot(data=df, x="Retail Price Unit", y= "Cup Equivalent Price")
plt.show()

# %%
#the form and its retail prices 
plt.title('The form and its Retail price')
sns.barplot(data=df, x="Form", y= "RetailPrice")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Item                  155 non-null    object
#  1   Form                  155 non-null    object
#  2   RetailPrice           155 non-null    float64
#  3   Retail Price Unit     155 non-null    object
#  4   Yield                 155 non-null    float64
#  5   Cup Equivalent Size   155 non-null    float64
#  6   Cup Equivalent Unit   155 non-null    object
#  7   Cup Equivalent Price  155 non-null    float64
# dtypes: float64(4), object(4)
# memory usage: 9.8+ KB

# %%
#the cup equivalent size and Form 
plt.title('The form and its Cup Equivalent sizes')
sns.barplot(data=df, x="Form", y= "Cup Equivalent Size")
plt.show()

# %%
#the cup equivalent size and Form 
plt.title('The Yield of the items')
sns.scatterplot(data=df, x="Yield", y= "Item")
plt.show()

# %%
df.hist(figsize=(10, 8))
# Out:
# array([[<Axes: title={'center': 'RetailPrice'}>,
#         <Axes: title={'center': 'Yield'}>],
#        [<Axes: title={'center': 'Cup Equivalent Size'}>,
#         <Axes: title={'center': 'Cup Equivalent Price'}>]], dtype=object)

# %%
plt.title('The Retail price and its Cup Equivalent Unit')
sns.barplot(data=df, x="Cup Equivalent Unit", y= "RetailPrice")
plt.show()
